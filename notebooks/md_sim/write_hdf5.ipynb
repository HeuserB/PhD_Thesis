# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import re

sys.path.append("../../src/md_sim")
from load_lammps_log import load_run, load_all_runs
from structure_analysis import store_as_hdf, combine_hdf5, load_hdf

# %%
dir                     =   "/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/strain_expansion/edip/"
run_data, thermo_dfs    =  load_all_runs(dir)
run_data
# Out:
# 3000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 3000K_8x8x8_100ns.log, grid constant: 3.3 T: 3000, cells: 8
# 5000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 5000K_8x8x8_100ns.log, grid constant: 3.3 T: 5000, cells: 8
# 4000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 4000K_8x8x8_100ns.log, grid constant: 3.3 T: 4000, cells: 8
# 2000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 2000K_8x8x8_100ns.log, grid constant: 3.3 T: 2000, cells: 8
# 3000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 3000K_8x8x8_100ns.log, grid constant: 3.25 T: 3000, cells: 8
# 5000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 5000K_8x8x8_100ns.log, grid constant: 3.25 T: 5000, cells: 8
# 4000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 4000K_8x8x8_100ns.log, grid constant: 3.25 T: 4000, cells: 8
# 2000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 2000K_8x8x8_100ns.log, grid constant: 3.25 T: 2000, cells: 8
# 3000K_8x8x8_100ns.dump
# ...

# %%
store_as_hdf("/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/strain_expansion/edip/", "edip", 100, run_group= "edip")
# Out:
# 3000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 3000K_8x8x8_100ns.log, grid constant: 3.3 T: 3000, cells: 8
# 5000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 5000K_8x8x8_100ns.log, grid constant: 3.3 T: 5000, cells: 8
# 4000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 4000K_8x8x8_100ns.log, grid constant: 3.3 T: 4000, cells: 8
# 2000K_8x8x8_100ns.dump
# Directory: grid_3_30 file : 2000K_8x8x8_100ns.log, grid constant: 3.3 T: 2000, cells: 8
# 3000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 3000K_8x8x8_100ns.log, grid constant: 3.25 T: 3000, cells: 8
# 5000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 5000K_8x8x8_100ns.log, grid constant: 3.25 T: 5000, cells: 8
# 4000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 4000K_8x8x8_100ns.log, grid constant: 3.25 T: 4000, cells: 8
# 2000K_8x8x8_100ns.dump
# Directory: grid_3_25 file : 2000K_8x8x8_100ns.log, grid constant: 3.25 T: 2000, cells: 8
# 3000K_8x8x8_100ns.dump
# ...

# %%
import os

# folder path
dir_path        = '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/'

# list to store files
file_list        = []
# Iterate directory
for file in os.listdir(dir_path):
    # check only text files
    if file.endswith('.h5'):
        file_list.append(f'{dir_path}{file}')
print(file_list)
# Out:
# ['/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_4_2000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_35_1000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_45_1000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_45_3000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_5_1000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_35_3000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edip_3_5_2000K_8x8x8.h5', '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_edip/edi
# ...

# %%
#store_as_hdf("/mnt/TOSHIBA_EXT/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_lcbop/", "lcbop", 100)
#combine_hdf5(outfile='/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_lcbop/lcbop.h5', h5files=file_list, run_group="lcbop")

# %%
#data, thermo_dfs       = load_run('/mnt/TOSHIBA_EXT/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_airebo_m/grid_3_45/3000K_8x8x8.log')
#data, thermo_dfs       = load_run('/mnt/TOSHIBA_EXT/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_airebo_m/grid_3_45/3000K_8x8x8_restart.log')
data, thermo_dfs        = load_run('/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_airebo_m/grid_3_45/3000K_8x8x8.log')
# Out:
# /mnt/TOSHIBA_EXT/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_airebo_m/grid_3_45
# File is a restart file!
# /mnt/TOSHIBA_EXT/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_airebo_m/grid_3_45
# /home/benjamin/Nextcloud/Work/W_PhD/W_PhD_Git/PhD_Git/PhD_Thesis/notebooks/md_sim/../../src/md_sim/load_lammps_log.py:88: RuntimeWarning: divide by zero encountered in double_scalars
#   drift               = linear_model[0]/n_atoms

# %%
data['lattice_constant']
# Out:
# 0    3.45
# Name: lattice_constant, dtype: float64

# %%
type(thermo_dfs[0])
# Out:
# list

# %%
import h5py as h5
filename            = '/media/benjamin/BenDrive/Nextcloud/Work/W_PhD/W_PhD_Analysis/Simulations/LAMMPS/free_expansion_lcbop/lcbop_3_35_1000K_8x8x8.h5'
with h5.File(filename, "r") as f:
        print(f.keys())
        print( (f[list(f.keys())[0]]).keys())
        print()
# Out:
# <KeysViewHDF5 ['3_35_1000K_8x8x8']>
# <KeysViewHDF5 ['structure_type', 'diamond_lattice', 'rdf_total', 'diamond_center', 'diamond_radius', 'diamond_onion', 'diamond_onion_outer_r', 'timesteps', 'thermo_equilibration', 'thermo_expansion']>
# 0

# %%
f
# Out:
# <Closed HDF5 file>
